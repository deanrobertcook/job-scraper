# %%
import pandas as pd

df = pd.read_json('output/page1a_flat.json')
df
# Out:
#     data_jobView_header_ageInDays data_jobView_header_employer_name  \
# 0                               6                     McMakler Gmbh
# 1                              13                              None
# 2                              15                     BCG Platinion
# 3                              21                       Vimcar GmbH
# 4                              19                   X24Factory GmbH
# 5                               7               clicks digital GmbH
# 6                               8                 MaibornWolff GmbH
# 7                              29                           E.ON AG
# 8                               2                           Zalando
# 9                               6                              None
# 10                              6                           Zalando
# 11                              6                              None
# 12                              7                         ONE LOGIC
# ...
